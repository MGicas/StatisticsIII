# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
notas = pd.read_csv("./datos.csv")

# %%
notas.head(15)
# Out:
#        nota1     nota2     nota3     nota4     nota5     nota6  paso
# 0   0.540253  9.977111  4.317857  3.221008  9.819762  5.590859     1
# 1   0.858280  4.144396  5.310199  8.118395  2.208087  4.618112     0
# 2   1.973619  0.312295  7.336357  5.976903  9.366790  5.428688     1
# 3   5.234680  6.500899  9.200685  6.572454  9.821463  0.377567     1
# 4   5.224433  9.740583  8.419047  9.559325  8.646798  5.896532     1
# 5   9.527151  5.023621  3.877708  4.133181  7.143100  2.973361     1
# 6   7.534349  5.213721  9.430391  8.946452  8.088744  7.324216     1
# 7   7.368605  0.163319  6.202159  9.512479  2.392936  0.027340     0
# 8   9.233863  7.595894  1.087520  0.014969  2.895761  9.416189     1
# 9   7.459771  6.770573  8.347506  4.980939  9.239861  5.638059     1
# 10  0.029512  6.536005  5.508781  3.742697  4.487964  0.116214     0
# 11  1.241353  8.776104  8.909979  8.707966  1.589908  5.627983     0
# 12  1.374154  4.510196  1.071840  3.459735  5.846647  7.430603     1
# ...

# %%
notas.corr()
# Out:
#           nota1     nota2     nota3     nota4     nota5     nota6      paso
# nota1  1.000000  0.128309  0.066357 -0.203151 -0.070897 -0.076398  0.118309
# nota2  0.128309  1.000000  0.216735 -0.253160  0.267186  0.200130  0.285092
# nota3  0.066357  0.216735  1.000000  0.376616  0.202147 -0.155800  0.122225
# nota4 -0.203151 -0.253160  0.376616  1.000000  0.047123  0.047592  0.181168
# nota5 -0.070897  0.267186  0.202147  0.047123  1.000000 -0.005312  0.633251
# nota6 -0.076398  0.200130 -0.155800  0.047592 -0.005312  1.000000  0.483557
# paso   0.118309  0.285092  0.122225  0.181168  0.633251  0.483557  1.000000

# %%
notas.corr()['paso']
# Out:
# nota1    0.118309
# nota2    0.285092
# nota3    0.122225
# nota4    0.181168
# nota5    0.633251
# nota6    0.483557
# paso     1.000000
# Name: paso, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(notas.corr(), annot=True, cmap='Greens', fmt=".2f", linewidths=.5)
plt.title('Matriz Correlación')
plt.show()
